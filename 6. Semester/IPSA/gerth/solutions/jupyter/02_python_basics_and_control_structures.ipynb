# %% [markdown]
# # Lecture 2 (Python basics and control structures)

# %% [markdown]
# ## Exercise 2.1 (increment a number)
#
# Create a program that asks the user for a number _x_ and prints _x_ + 1. Example:
#
#     A number x: 4
#     x + 1 = 5
#
# _Hint_. Use the function `input`. Recall that the function `input` returns a `str`.

# %%
x = int(input('A number x: '))
print('x + 1 =', x + 1)
# Out:
# x + 1 = 5

# %% [markdown]
# ## Exercise 2.2 (sum of two numbers)
#
# Create a program that asks the user for two numbers and then prints their sum.
#
# _Hint_. Use the function `input`. Recall that the function `input` returns a `str`.

# %%
print('Enter two numbers x and y')
x = int(input('x = '))
y = int(input('y = '))
print(x, '+', y, '=', x + y)
# Out:
# Enter two numbers x and y
# 4 + 4 = 8

# %% [markdown]
# ## Exercise 2.3 (count)
#
# Create a program that ask a user for a positive integer _n_, and prints the numbers 1, 2, ..., _n_ each on a separate line. Example:
#
#     A positive integer n: 4
#     1
#     2
#     3
#     4
# _Hint_. Use a `while`-loop.

# %%
n = int(input('A positive integer n: '))
i = 1
while i <= n:
    print(i)
    i = i + 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## Exercise 2.4 (sum of _k_ numbers)
#
# Create a program that adds a user specified number of numbers. The program should first ask the user for a number _k_, and then _k_ times ask the user for a number, and finally print the sum of the _k_ numbers.
#
# _Hint_. Use a `while`-loop.

# %%
k = int(input('Number of numbers to add: '))

i = 1
the_sum = 0
while i <= k:
    value = int(input('Number ' + str(i) + ': '))
    the_sum = the_sum + value
    i = i + 1

print('sum =', the_sum)
# Out:
# sum = 13

# %% [markdown]
# ## Exercise 2.5 (intersection of two intervals)
#
# Write a program that determines if two intervals [_a_, _b_] and [_c_, _d_] overlap, where _a_ ≤ _b_ and _c_ ≤ _d_.
# The program should ask the user for the four end-points _a_, _b_, _c_ and _d_ of the two intervals, and print if the two intervals overlap or not. If the two intervals overlap, the program should print the interval where the two input intervals overlap.
#
# _Hint_. Use one or more `if`-statements.
#
# _Examples_:
#
#     [2, 4] and [6, 9] do not overlap
#     [5, 7] and [1, 3] do not overlap
#     [4, 8] and [-6, 2] do not overlap
#     [2, 5] and [3, 9] overlap in the interval [3, 5]
#     [3, 6] and [1, 3] overlap in the interval [3, 3]
#     [1, 8] and [2, 6] overlap in the interval [2, 6]

# %%
print('Input the endpoints of two intervals [a, b] and [c, d]')

a = int(input('a: '))
b = int(input('b: '))
c = int(input('c: '))
d = int(input('d: '))

#     a---------------b
#              c----------------------d
#              |      |
#    max(a,c)=left   right=min(b,d)

if c < a:
    left = a
else:
    left = c

if b < d:
    right = b
else:
    right = d

intervals = '[' + str(a) + ', ' + str(b) + '] and [' + str(c) + ', ' + str(d) + ']'

if right < left:
    print(intervals, 'do not overlap')
else:
    print(intervals, 'overlap in the interval [' + str(left) + ', ' + str(right) + ']')
# Out:
# Input the endpoints of two intervals [a, b] and [c, d]
# [1, 3] and [2, 4] overlap in the interval [2, 3]

# %% [markdown]
# ## Exercise 2.6 (integer square root)
#
# Consider the following program for finding the integer square root of a non-negative integer:
#
#     x = int(input('x: '))
#
#     low = 0
#     high = x + 1
#
#     while True:  # low <= sqrt(x) < high
#         if low + 1 == high:
#             break
#
#         mid = (high + low) // 2
#
#         if mid * mid <= x:
#             low = mid
#             continue
#
#         high = mid
#
#     print(low)  # low = floor(sqrt(x))
#
# 1.  Walk through and understand the program.
#
# 2.  Try to simplify the program, getting rid of the `break` and `continue` statements.

# %%
x = int(input('x: '))

low = 0
high = x + 1

while low + 1 < high:  # low <= sqrt(x) < high
    mid = (high + low) // 2

    if mid * mid <= x:
        low = mid
    else:
        high = mid

print(low)  # low = floor(sqrt(x))
# Out:
# 31

# %% [markdown]
# ## Exercise 2.7 (primality test)
#
# Write a naive program that tests if a small number _x_ ≥ 2 is a prime number.
#
# Recall that a number is a [prime number](https://en.wikipedia.org/wiki/Prime_number) if and only if the only numbers dividing the number is 1 and the number itself, like the numbers 2, 3, 5, 7, 11, 13...
#
# The program should ask the user for the number _x_ and print whether the number is a prime or not. If _x_ is not a prime, it should print a divisor/factor in the range [2, _x_ - 1].
#
# _Hint_. Try all relevant factors. Use the `%` operator to compute the remainder by integer division, e.g. `13 % 5 == 3`.

# %%
x = int(input('number: '))

factor = 2

while x % factor != 0 and factor * factor <= x:
    factor += 1

if factor == x or factor * factor > x:
    print(x, 'is a prime')
else:
    print(x, 'is composite, and divisible by', factor)
# Out:
# 1000000007 is a prime

# %% [markdown]
# ## Exercise 2.8 (integer factorization)
#
# Write a program that, given a positive integer _x_, prints the prime factors of that number.
# Recall that any positive number has a unique prime factorization, e.g. 126 = 2 * 3 * 3 * 7.
#
# The program should ask the user for the integer _x_, and then print each prime factor.
# Note that for _x_ = 126, the prime factor 3 should be printed two times.
#
# _Hint_. Repeatedly divide _x_ by 2 until 2 is not a prime factor any longer. Repeat the same for 3, 4, 5,... Note that 4 = 2 * 2 is not a prime number. But since its prime factors cannot be divisors of _x_ divided by the prime factors found so far, then we will not find 4 (and any other composite number) as a prime divisor of _x_.

# %%
x = int(input('Number to factorize: '))

factor = 2

print('Factors:', end=' ')
while x != 1:
    while x % factor != 0:
        factor += 1

    x = x // factor
    print(x, factor)
# Out:
# Factors: 4491878491877 2
# 641696927411 7
# 37746878083 17
# 920655563 41
# 3397253 271
# 1 3397253

# %% [markdown]
# ## Exercise 2.9* (Newton-Raphson square root)
#
# Use the Newton-Raphson method to compute the square root of a float _n_ ≥ 1.0, by finding a root of the function
# _f_(_x_) = _x_<sup>2</sup> - _n_ and letting your initial approximation of the root be _x_ = _n_.
# Recall _f_'(_x_) = 2 * _x_. In your computations you can use +, -, *, and /.
#
# You can compare your result to the result of the builtin `sqrt` function in the `math` module using:
#
#     import math
#     print(math.sqrt(n))

# %%
# f(x) = x^2 - n
# f'(x) = 2*x
# Newton-Raphson:
#  x := x - f(x) / f'(x)
#     = x - (x^2 - n) / (2 * x)
#     = x - x / 2 + n / (2 * x)
#     = (x + n / x) / 2

import math

n = float(input('n = '))

last = n + 1
x = n
while x < last:
    print(x)
    last = x
    x = (x + n / x) / 2

print('apx. sqrt(', n, ') = ', x, sep='')
print('math.sqrt(', n, ') = ', math.sqrt(n), sep='')
# Out:
# 29387498327498.0
# 14693749163749.5
# 7346874581875.75
# 3673437290939.875
# 1836718645473.9375
# 918359322744.9688
# 459179661388.4844
# 229589830726.2422
# 114794915427.1211
# 57397457841.56055
# 28698729176.780273
# 14349365100.390131
# 7174683574.195017
# 3587343835.097119
# 1793676013.5454416
# 896846198.747778
# 448439483.1743492
# 224252507.99092597
# 112191777.22771305
# 56226858.54344348
# 28374758.991083454
# 14705225.274191914
# 8351832.226716045
# 5935260.502095415
# 5443300.722219351
# 5421069.319127127
# 5421023.734459752
# 5421023.734268095
# apx. sqrt(29387498327498.0) = 5421023.734268095
# math.sqrt(29387498327498.0) = 5421023.734268094

# %% [markdown]
# ## Exercise 2.10** (Stirlings's approximation)
#
# [Stirling's approximation](https://en.wikipedia.org/wiki/Stirling%27s_approximation) states that _n_! can be approximated by _S_(_n_) = (2 _&pi;_ _n_)<sup>0.5</sup> &middot; (_n_ / _e_)<sup>_n_</sup>.
#
# Write a program that asks the user for an _n_ and prints the ratio _n_! / _S_(_n_), i.e. how good an approximation _S_(_n_) is to _n_!.
#
# Some example outputs:
#
#     1! / S(1) = 1.08443755
#     10! / S(10) = 1.00836536
#     100! / S(100) = 1.00083368
#     1000! / S(1000) = 1.00008334
#     10000! / S(10000) = 1.00000833
#     100000! / S(100000) = 1.00000083
#
# _Note_: Use `import math` to get access to the constants `math.pi` and `math.e`.
#
# _Warning_: Computing the ratio for larger _n_ can be tricky.
#
# This exercise is inspired by a problem from [Kattis](https://open.kattis.com/problems/stirlingsapproximation).

# %%
from math import pi, e, log, factorial

n = 2489


# Solution 2, fails for larger n
#  n = 2489 => outputs 1.7169521121244922e+52 (huge!!!)
#  n = 2490 => outputs 0.0

result = 1 / (2 * pi * n) ** 0.5
i = 1
while i <= n:
    result = result * i * e / n
    i = i + 1
print(result)

# Solution 1, fails for medium n
#  n = 170 => 1.0004903156784803
#  n = 171 => Overflow
# Out:
# 1.0016680340707416
# 1.001668034070732
# 1.0016680340707338
# 1.0016680340707314

# %% [markdown]
# ## Exercise 2.11 - handin 1 (down payment)
#
# Write a program to compute how many months it takes to pay down a loan, that has a fixed monthly interest rate, and the borrower makes a fixed monthly payment. The program should ask the user for three values: The size of the initial loan, the monthly interest rate in percent, and the size of the monthly payment of the borrower. The program should output for each month the size of the remaining loan.
#
# _Handin format_. The handin should consist of a **single Python file**. The files should start with a Python docstring (string in triple quotes, `"""` or `'''`) containing the **study ids** and **names** of the students who made the handin. A handin group consists of 1-3 students. Furthermore the docstring must contain a short **reflection** (5-10 lines) on your solution to the exercise. This could be a short discussion of the design choices you made during your implementation, the problems you encountered, what were the hard and easy parts to get your solution to work, what restrictions on the user input did you make, limitations in your implementation, what language features were particularly useful, ... A template for the handin is below.  The **filename** of a submission must contain the names of all group members and their study id.
#
#     '''
#     HANDIN 1 (down payment)
#
#     This handin is done by (study ids and names of up to three students):
#
#         201500000 student name
#         201600000 student name
#         201400000 student name
#
#     Reflection upon solution:
#
#         Reflection on your solution (5-10 lines), e.g. implementation
#         decisions, hard/easy parts, input restrictions, limitations, ...
#     '''
#
#     loan_input = input('Initial loan: ')
#     ...

# %%
loan = float(input('Initial loan: '))
rate = float(input('Monthly interest rate %: '))
monthly_payment = float(input('Monthly payment: '))

min_monthly_payment = loan * rate / 100

if monthly_payment <= min_monthly_payment:
    print('Monthly payment too low - must be more than', min_monthly_payment)
else:
    print('Months, payment and remaining loan')
    months = 0
    while loan > 0:
        interest = loan * rate / 100
        loan = loan + interest
        payment = min(monthly_payment, loan)
        loan = loan - payment
        months += 1
        print(months, payment, loan)
# Out:
# Months, payment and remaining loan
# 1 100.0 950.0
# 2 100.0 897.5
# 3 100.0 842.375
# 4 100.0 784.49375
# 5 100.0 723.7184374999999
# 6 100.0 659.9043593749999
# 7 100.0 592.8995773437499
# 8 100.0 522.5445562109375
# 9 100.0 448.6717840214843
# 10 100.0 371.1053732225585
# 11 100.0 289.6606418836864
# 12 100.0 204.14367397787072
# 13 100.0 114.35085767676426
# 14 100.0 20.06840056060247
# 15 21.071820588632594 0.0
