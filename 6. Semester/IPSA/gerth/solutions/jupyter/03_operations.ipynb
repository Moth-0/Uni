# %% [markdown]
# # Lecture 3 (Operations)

# %% [markdown]
# ## Exercise 3.1 (text formatting)
#
# Consider the below code. Run the code and explain the output.
#
#     from math import pi
#     print('A string: "%s"' % 'Hello World')
#     print('An integer: %s' % 27)
#     print('A float: %s' % 27.0)
#     print('A float: %s' % pi)
#     print('A float: %s' % pi * 2)
#     print('A float: %s' % (pi * 2))
#     print('A float: %.2f' % pi)
#     print('A float: [%5.2f]' % pi)
#     print('A float: [%+6.2f]' % pi)
#     print('A float: [%+.2f]' % pi)
#     print('A float: [%08.2f]' % pi)
#     print('An integer: [%08d]' % 42)
#
# Write similar expressions using [f-strings](https://docs.python.org/3/reference/lexical_analysis.html#formatted-string-literals).
#
# _Hint_. See [pyformat.info](https://pyformat.info/) for examples of string formatting.

# %%
from math import pi
print('A string: "%s"' % 'Hello World')
print('An integer: %s' % 27)
print('A float: %s' % 27.0)
print('A float: %s' % pi)
print('A float: %s' % pi * 2)
print('A float: %s' % (pi * 2))
print('A float: %.2f' % pi)
print('A float: [%5.2f]' % pi)
print('A float: [%+6.2f]' % pi)
print('A float: [%+.2f]' % pi)
print('A float: [%08.2f]' % pi)
print('An integer: [%08d]' % 42)
print()
print(f'A string: "{"Hello World"}"')
print(f'An integer: {27}')
print(f'A float: {27.0}')
print(f'A float: {pi}')
print(f'A float: {pi}' * 2)
print(f'A float: {pi * 2}')
print(f'A float: {pi:.2f}')
print(f'A float: [{pi:5.2f}]')
print(f'A float: [{pi:+6.2f}]')
print(f'A float: [{pi:+.2f}]')
print(f'A float: [{pi:08.2f}]')
print(f'An integer: [{42:08d}]')
# Out:
# A string: "Hello World"
# An integer: 27
# A float: 27.0
# A float: 3.141592653589793
# A float: 3.141592653589793A float: 3.141592653589793
# A float: 6.283185307179586
# A float: 3.14
# A float: [ 3.14]
# A float: [ +3.14]
# A float: [+3.14]
# A float: [00003.14]
# An integer: [00000042]
#
# A string: "Hello World"
# An integer: 27
# A float: 27.0
# A float: 3.141592653589793
# A float: 3.141592653589793A float: 3.141592653589793
# A float: 6.283185307179586
# A float: 3.14
# A float: [ 3.14]
# A float: [ +3.14]
# A float: [+3.14]
# A float: [00003.14]
# An integer: [00000042]
