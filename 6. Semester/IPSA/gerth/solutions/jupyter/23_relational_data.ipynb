# %% [markdown]
# # Lecture 23 (Relational data)

# %% [markdown]
# ## Exercise 23.1 (World Bank data)
#
# Plot the development in the population in the Scandinavian countries (Norway, Denmark, Sweden, Finland, Iceland) since 1960 until last year.
#
# Use the pandas data reader for the [World Bank](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#world-bank) data to get the population data. The indicator is `SP.POP.TOTL`.
#
# _Hint_. Use the data frame methods [`unstack`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.unstack.html) and [`plot`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html).

# %%
import wbgapi as wb
import matplotlib.pyplot as plt

countries = ['DNK', 'FIN', 'ISL', 'NOR', 'SWE']

data = wb.data.DataFrame('SP.POP.TOTL', countries, time=range(1960, 2026))

data.columns = [int(year.replace('YR', '')) for year in data.columns]


plt.figure(figsize=(12, 7))
for country in countries:
    plt.plot(data.columns, data.T[country] / 1e6, label=country, linewidth=2)

plt.title('Population')
plt.xlabel('Year')
plt.ylabel('Population (Millions)')
plt.grid(True, linestyle='--')
plt.legend(title="Countries")
plt.show()
