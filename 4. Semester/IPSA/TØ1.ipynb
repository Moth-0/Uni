# %% [markdown]
# Opg 1

# %%
x1 = int(input("Num 1: " ))
x2 = int(input("Num 2: " ))
print("Sum: " + str(x1+x2))
# Out:
# Sum: 3

# %% [markdown]
# Opg 2

# %%
k = int(input("How many numbers: "))
sum = 0
for i in range(k): 
    x = int(input("Number to add: "))
    sum += x 

print(sum)
# Out:
# 2

# %%
k = int(input("How many numbers: "))
sum = 0
while k > 0:
    x = int(input("Number to add: "))
    sum += x 
    k -= 1

print(sum)
# Out:
# 3

# %% [markdown]
# Opg 3
